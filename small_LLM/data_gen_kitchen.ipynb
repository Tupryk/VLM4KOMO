# %%
import os
import json
import numpy as np
import robotic as ry
from tqdm import tqdm
from lookup import features, contraint_types
from komo_generators import generate_random_komo, generate_random_pick, generate_random_pivot
from random_kitchen_generator import generate_random_kitchen, load_single_from_type
from MuJoCo2Rai.io import load_kitchen
# Out:
# Mujoco2Rai package has been imported!

# %%
C = load_kitchen()
C.addFile(ry.raiPath("scenarios/pandaOmnibase.g"))
C.view(True)

features["qItself"][1] = len(C.getJointState())
# Out:
# ===================== ../kitchen_dataset/RUSTIC_ONE_WALL_SMALL.xml
# | mujoco {'model': 'base'}
# |   compiler {'angle': 'radian', 'meshdir': 'meshes/'}
# |   option {'impratio': '20', 'density': '1.2', 'viscosity': '2e-05', 'cone': 'elliptic'}
# |   size {'njmax': '5000', 'nconmax': '5000'}
# |   visual {}
# |     map {'znear': '0.001'}
# |   asset {}
# |     texture {'type': 'skybox', 'builtin': 'flat', 'rgb1': '1 1 1', 'rgb2': '1 1 1', 'width': '256', 'height': '1536'}
# ../textures/wood/wood_planks_wall.png
# |     texture {'type': '2d', 'name': 'wall_room_wall', 'file': '../kitchen_dataset/../textures/wood/wood_planks_wall.png'}
# ../textures/flat/light_gray.png
# |     texture {'type': '2d', 'name': 'wall_backing_room_wall', 'file': '../kitchen_dataset/../textures/flat/light_gray.png'}
# ../textures/wood/wood_planks_wall.png
# |     texture {'type': '2d', 'name': 'wall_left_room_wall', 'file': '../kitchen_dataset/../textures/wood/wood_planks_wall.png'}
# ../textures/flat/light_gray.png
# |     texture {'type': '2d', 'name': 'wall_left_backing_room_wall', 'file': '../kitchen_dataset/../textures/flat/light_gray.png'}
# ../textures/wood/wood_planks_wall.png
# |     texture {'type': '2d', 'name': 'wall_right_room_wall', 'file': '../kitchen_dataset/../textures/wood/wood_planks_wall.png'}
# ../textures/flat/light_gray.png
# |     texture {'type': '2d', 'name': 'wall_right_backing_room_wall', 'file': '../kitchen_dataset/../textures/flat/light_gray.png'}
# ../textures/wood/wood_planks_3.png
# |     texture {'type': '2d', 'name': 'floor_room_wall', 'file': '../kitchen_dataset/../textures/wood/wood_planks_3.png'}
# ../textures/flat/light_gray.png
# |     texture {'type': '2d', 'name': 'floor_backing_room_wall', 'file': '../kitchen_dataset/../textures/flat/light_gray.png'}
# ../fixtures/accessories/outlets/simple_white/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'outlet_room_tex-outlet', 'file': '../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/material_0.png'}
# ../fixtures/accessories/outlets/simple_white/visuals/image0.png
# |     texture {'type': '2d', 'name': 'outlet_room_image0', 'file': '../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/image0.png'}
# ../fixtures/accessories/outlets/simple_white/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'outlet_2_room_tex-outlet', 'file': '../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/material_0.png'}
# ../fixtures/accessories/outlets/simple_white/visuals/image0.png
# |     texture {'type': '2d', 'name': 'outlet_2_room_image0', 'file': '../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/image0.png'}
# ../fixtures/accessories/light_switches/white_wide_switch/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'light_switch_room_tex-light_switch', 'file': '../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/material_0.png'}
# ../fixtures/accessories/light_switches/white_wide_switch/visuals/image0.png
# |     texture {'type': '2d', 'name': 'light_switch_room_image0', 'file': '../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/image0.png'}
# ../fixtures/accessories/light_switches/white_wide_switch/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'light_switch_2_room_tex-light_switch', 'file': '../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/material_0.png'}
# ../fixtures/accessories/light_switches/white_wide_switch/visuals/image0.png
# |     texture {'type': '2d', 'name': 'light_switch_2_room_image0', 'file': '../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/image0.png'}
# ../fixtures/sinks/concrete_sink/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'sink_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/material_0.png'}
# ../fixtures/sinks/concrete_sink/visuals/image0.png
# |     texture {'type': '2d', 'name': 'sink_main_group_image0', 'file': '../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/image0.png'}
# ../textures/wood/greenheart_wood_grain.png
# |     texture {'type': '2d', 'name': 'wood/greenheart_wood_grain_2d', 'file': '../kitchen_dataset/../textures/wood/greenheart_wood_grain.png'}
# ../textures/flat/light_green.png
# |     texture {'type': 'cube', 'name': 'flat/light_green', 'file': '../kitchen_dataset/../textures/flat/light_green.png'}
# ../fixtures/stoves/square_gas/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'stove_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/material_0.png'}
# ../fixtures/stoves/square_gas/visuals/image0.png
# |     texture {'type': '2d', 'name': 'stove_main_group_image0', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/image0.png'}
# ../fixtures/stoves/square_gas/visuals/image4.png
# |     texture {'type': '2d', 'name': 'stove_main_group_image4', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/image4.png'}
# ../fixtures/fridges/pack_2/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'fridge_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/fridges/pack_2/visuals/material_0.png'}
# ../fixtures/fridges/pack_2/visuals/image27.png
# |     texture {'type': '2d', 'name': 'fridge_main_group_image27', 'file': '../kitchen_dataset/../fixtures/fridges/pack_2/visuals/image27.png'}
# ../fixtures/fridges/pack_2/visuals/image30.png
# |     texture {'type': '2d', 'name': 'fridge_main_group_image30', 'file': '../kitchen_dataset/../fixtures/fridges/pack_2/visuals/image30.png'}
# ../textures/flat/light_green.png
# |     texture {'type': '2d', 'name': 'flat/light_green_2d', 'file': '../kitchen_dataset/../textures/flat/light_green.png'}
# ../textures/metals/bright_metal.png
# |     texture {'type': 'cube', 'name': 'metals/bright_metal', 'file': '../kitchen_dataset/../textures/metals/bright_metal.png'}
# ../fixtures/microwaves/gray/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'microwave_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/microwaves/gray/visuals/material_0.png'}
# ../fixtures/microwaves/gray/visuals/image0.png
# |     texture {'type': '2d', 'name': 'microwave_main_group_image0', 'file': '../kitchen_dataset/../fixtures/microwaves/gray/visuals/image0.png'}
# ../textures/flat/light_green.png
# |     texture {'type': 'cube', 'name': 'box', 'file': '../kitchen_dataset/../textures/flat/light_green.png'}
# ../textures/ceramic.png
# |     texture {'type': '2d', 'name': 'tex_2d', 'file': '../kitchen_dataset/../textures/ceramic.png'}
# ../fixtures/dishwashers/pack_2/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'dishwasher_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/dishwashers/pack_2/visuals/material_0.png'}
# ../fixtures/dishwashers/pack_2/visuals/image0.png
# |     texture {'type': '2d', 'name': 'dishwasher_main_group_image0', 'file': '../kitchen_dataset/../fixtures/dishwashers/pack_2/visuals/image0.png'}
# ../fixtures/dishwashers/pack_2/visuals/image23.png
# |     texture {'type': '2d', 'name': 'dishwasher_main_group_image23', 'file': '../kitchen_dataset/../fixtures/dishwashers/pack_2/visuals/image23.png'}
# ../fixtures/coffee_machines/nespresso/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'coffee_machine_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/material_0.png'}
# ../fixtures/coffee_machines/nespresso/visuals/image0.png
# |     texture {'type': '2d', 'name': 'coffee_machine_main_group_image0', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/image0.png'}
# ../fixtures/toasters/basic_popup_2/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'toaster_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/material_0.png'}
# ../fixtures/toasters/basic_popup_2/visuals/image0.png
# |     texture {'type': '2d', 'name': 'toaster_main_group_image0', 'file': '../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/image0.png'}
# ../fixtures/toasters/basic_popup_2/visuals/image3.png
# |     texture {'type': '2d', 'name': 'toaster_main_group_image3', 'file': '../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/image3.png'}
# ../fixtures/accessories/knife_blocks/light_wood_3/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'knife_block_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/accessories/knife_blocks/light_wood_3/visuals/material_0.png'}
# ../fixtures/accessories/knife_blocks/light_wood_3/visuals/image0.png
# |     texture {'type': '2d', 'name': 'knife_block_main_group_image0', 'file': '../kitchen_dataset/../fixtures/accessories/knife_blocks/light_wood_3/visuals/image0.png'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/material_0.png
# |     texture {'type': '2d', 'name': 'paper_towel_main_group_tex-model', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/material_0.png'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/image0.png
# |     texture {'type': '2d', 'name': 'paper_towel_main_group_image0', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/image0.png'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/image1.png
# |     texture {'type': '2d', 'name': 'paper_towel_main_group_image1', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/image1.png'}
# |     material {'name': 'wall_room_wall_mat', 'texture': 'wall_room_wall', 'texuniform': 'true', 'shininess': '0.01', 'reflectance': '0.1'}
# |     material {'name': 'wall_backing_room_wall_mat', 'texture': 'wall_backing_room_wall', 'texuniform': 'true', 'shininess': '0.01', 'reflectance': '0.1'}
# |     material {'name': 'wall_left_room_wall_mat', 'texture': 'wall_left_room_wall', 'texuniform': 'true', 'shininess': '0.01', 'reflectance': '0.1'}
# |     material {'name': 'wall_left_backing_room_wall_mat', 'texture': 'wall_left_backing_room_wall', 'texuniform': 'true', 'shininess': '0.01', 'reflectance': '0.1'}
# |     material {'name': 'wall_right_room_wall_mat', 'texture': 'wall_right_room_wall', 'texuniform': 'true', 'shininess': '0.01', 'reflectance': '0.1'}
# |     material {'name': 'wall_right_backing_room_wall_mat', 'texture': 'wall_right_backing_room_wall', 'texuniform': 'true', 'shininess': '0.01', 'reflectance': '0.1'}
# |     material {'name': 'floor_room_wall_mat', 'texture': 'floor_room_wall', 'texuniform': 'true', 'texrepeat': '0.75 0.75'}
# |     material {'name': 'floor_backing_room_wall_mat', 'texture': 'floor_backing_room_wall', 'texuniform': 'true', 'texrepeat': '0.75 0.75'}
# |     material {'name': 'outlet_room_outlet', 'texture': 'outlet_room_tex-outlet', 'reflectance': '0.5'}
# |     material {'name': 'outlet_2_room_outlet', 'texture': 'outlet_2_room_tex-outlet', 'reflectance': '0.5'}
# |     material {'name': 'light_switch_room_light_switch', 'texture': 'light_switch_room_tex-light_switch', 'reflectance': '0.5'}
# |     material {'name': 'light_switch_room_lightswitch', 'texture': 'light_switch_room_image0', 'shininess': '0.25'}
# |     material {'name': 'light_switch_2_room_light_switch', 'texture': 'light_switch_2_room_tex-light_switch', 'reflectance': '0.5'}
# |     material {'name': 'light_switch_2_room_lightswitch', 'texture': 'light_switch_2_room_image0', 'shininess': '0.25'}
# |     material {'name': 'sink_main_group_model', 'texture': 'sink_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'sink_main_group_m_sink', 'texture': 'sink_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'counter_main_main_group_counter_top', 'texture': 'wood/greenheart_wood_grain_2d', 'texuniform': 'true', 'texrepeat': '3 3', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'counter_main_main_group_counter_base', 'texture': 'flat/light_green', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stove_main_group_model', 'texture': 'stove_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'stove_main_group_TX_Stove_Small', 'texture': 'stove_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'stove_main_group_TX_Stove_Small_Glass', 'texture': 'stove_main_group_image4', 'shininess': '0.25'}
# |     material {'name': 'counter_right_main_group_counter_top', 'texture': 'wood/greenheart_wood_grain_2d', 'texuniform': 'true', 'texrepeat': '3 3', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'counter_right_main_group_counter_base', 'texture': 'flat/light_green', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'fridge_main_group_model', 'texture': 'fridge_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'fridge_main_group_TX_Fridge_2_1', 'texture': 'fridge_main_group_image27', 'shininess': '0.25'}
# |     material {'name': 'fridge_main_group_TX_Fridge_2_2', 'texture': 'fridge_main_group_image30', 'shininess': '0.25'}
# |     material {'name': 'fridge_housing_main_group_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'cab_1_main_group_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'cab_1_main_group_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_1_main_group_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_2_main_group_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'cab_2_main_group_left_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_2_main_group_left_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_2_main_group_right_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_2_main_group_right_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_main_main_group_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'cab_main_main_group_left_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_main_main_group_left_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_main_main_group_right_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_main_main_group_right_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'microwave_main_group_model', 'texture': 'microwave_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'microwave_main_group_Baked_Microwave', 'texture': 'microwave_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'microwave_main_group_Door_Inside', 'shininess': '0.25', 'rgba': '0.3059 0.3059 0.3059 1'}
# |     material {'name': 'cab_micro_main_group_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'cab_micro_main_group_left_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_micro_main_group_left_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_micro_main_group_right_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_micro_main_group_right_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_3_main_group_mat', 'texture': 'wood/greenheart_wood_grain_2d', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_3_main_group_shelf_0_mat', 'texture': 'wood/greenheart_wood_grain_2d', 'texuniform': 'true', 'texrepeat': '3 3', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_3_main_group_shelf_1_mat', 'texture': 'wood/greenheart_wood_grain_2d', 'texuniform': 'true', 'texrepeat': '3 3', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_3_main_group_shelf_2_mat', 'texture': 'wood/greenheart_wood_grain_2d', 'texuniform': 'true', 'texrepeat': '3 3', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_4_main_group_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'cab_4_main_group_left_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_4_main_group_left_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'cab_4_main_group_right_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'cab_4_main_group_right_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'box_mat', 'texture': 'box', 'shininess': '0.1'}
# |     material {'name': 'stack_1_main_group_1_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_1_main_group_1_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_1_main_group_1_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_1_main_group_2_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_1_main_group_2_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_1_main_group_2_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_1_main_group_3_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_1_main_group_3_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_1_main_group_3_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_1_main_group_4_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_1_main_group_4_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_1_main_group_4_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_2_main_group_1_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_2_main_group_1_left_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_2_main_group_1_left_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_2_main_group_1_right_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_2_main_group_1_right_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_2_main_group_2_mat', 'texture': 'flat/light_green', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_2_main_group_2_mat_uniform', 'texture': 'tex_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_2_main_group_2_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'dishwasher_main_group_model', 'texture': 'dishwasher_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'dishwasher_main_group_TX_Dishwasher_1_1.001', 'texture': 'dishwasher_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'dishwasher_main_group_TX_Dishwasher_1_2.001', 'texture': 'dishwasher_main_group_image23', 'shininess': '0.25'}
# |     material {'name': 'stack_3_main_group_1_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_3_main_group_1_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_3_main_group_1_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_4_main_group_1_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_4_main_group_1_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_4_main_group_1_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'stack_4_main_group_2_mat', 'texture': 'flat/light_green', 'shininess': '0.1'}
# |     material {'name': 'stack_4_main_group_2_door_mat', 'texture': 'flat/light_green_2d', 'texuniform': 'true', 'texrepeat': '4 4', 'shininess': '0.1', 'reflectance': '0.1'}
# |     material {'name': 'stack_4_main_group_2_door_handle_mat', 'texture': 'metals/bright_metal', 'shininess': '0.8', 'reflectance': '0.8'}
# |     material {'name': 'coffee_machine_main_group_model', 'texture': 'coffee_machine_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'coffee_machine_main_group_Black_Plastic', 'texture': 'coffee_machine_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'coffee_machine_main_group_Chrome', 'shininess': '1'}
# |     material {'name': 'coffee_machine_main_group_Perspex', 'shininess': '1', 'rgba': '0.15482 0.15482 0.15482 1'}
# |     material {'name': 'coffee_machine_main_group_Water', 'shininess': '1'}
# |     material {'name': 'coffee_machine_main_group_White_Plastic', 'shininess': '0.0491555', 'rgba': '0.8 0.686012 0.55947 1'}
# |     material {'name': 'toaster_main_group_model', 'texture': 'toaster_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'toaster_main_group_Material_38', 'texture': 'toaster_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'toaster_main_group_Material_39', 'texture': 'toaster_main_group_image3', 'shininess': '0.25'}
# |     material {'name': 'knife_block_main_group_model', 'texture': 'knife_block_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'knife_block_main_group_Knife_rack', 'texture': 'knife_block_main_group_image0', 'shininess': '0.25'}
# |     material {'name': 'paper_towel_main_group_model', 'texture': 'paper_towel_main_group_tex-model', 'reflectance': '0.5'}
# |     material {'name': 'paper_towel_main_group_metal', 'shininess': '0.0553676', 'rgba': '0.35595 0.35595 0.35595 1'}
# |     material {'name': 'paper_towel_main_group_paperSide', 'texture': 'paper_towel_main_group_image0', 'shininess': '0'}
# |     material {'name': 'paper_towel_main_group_paperTopAndBottom', 'texture': 'paper_towel_main_group_image1', 'shininess': '0'}
# |     material {'name': 'paper_towel_main_group_paperboard', 'shininess': '0', 'rgba': '0.327778 0.266356 0.198069 1'}
# ../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj
# |     mesh {'name': 'outlet_room_outlet_0_vis', 'file': '../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj', 'scale': '0.15 0.15 0.15'}
# ../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj
# |     mesh {'name': 'outlet_2_room_outlet_0_vis', 'file': '../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj', 'scale': '0.15 0.15 0.15'}
# ../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj
# |     mesh {'name': 'light_switch_room_light_switch_0_vis', 'file': '../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj', 'scale': '0.15 0.15 0.15'}
# ../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj
# |     mesh {'name': 'light_switch_2_room_light_switch_0_vis', 'file': '../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj', 'scale': '0.15 0.15 0.15'}
# ../fixtures/sinks/concrete_sink/visuals/model_0.obj
# |     mesh {'name': 'sink_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/model_0.obj', 'scale': '0.916667 0.916667 0.916667'}
# ../fixtures/sinks/concrete_sink/visuals/spout_0.obj
# |     mesh {'name': 'sink_main_group_spout_0_vis', 'file': '../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/spout_0.obj', 'scale': '0.916667 0.916667 0.916667'}
# ../fixtures/sinks/concrete_sink/visuals/handle_0.obj
# |     mesh {'name': 'sink_main_group_handle_0_vis', 'file': '../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/handle_0.obj', 'scale': '0.916667 0.916667 0.916667'}
# ../fixtures/stoves/square_gas/visuals/model_0.obj
# |     mesh {'name': 'stove_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/model_0.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/stoves/square_gas/visuals/model_1.obj
# |     mesh {'name': 'stove_main_group_model_1_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/model_1.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/stoves/square_gas/visuals/knob_rear_right_0.obj
# |     mesh {'name': 'stove_main_group_knob_rear_right_0_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/knob_rear_right_0.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/stoves/square_gas/visuals/knob_dummy_0.obj
# |     mesh {'name': 'stove_main_group_knob_dummy_0_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/knob_dummy_0.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/stoves/square_gas/visuals/knob_front_left_0.obj
# |     mesh {'name': 'stove_main_group_knob_front_left_0_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/knob_front_left_0.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/stoves/square_gas/visuals/knob_front_right_0.obj
# |     mesh {'name': 'stove_main_group_knob_front_right_0_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/knob_front_right_0.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/stoves/square_gas/visuals/knob_rear_left_0.obj
# |     mesh {'name': 'stove_main_group_knob_rear_left_0_vis', 'file': '../kitchen_dataset/../fixtures/stoves/square_gas/visuals/knob_rear_left_0.obj', 'scale': '0.897959 0.897959 0.897959'}
# ../fixtures/fridges/pack_2/visuals/model_0.obj
# |     mesh {'name': 'fridge_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/fridges/pack_2/visuals/model_0.obj', 'scale': '1.75 1.75 1.75'}
# ../fixtures/fridges/pack_2/visuals/model_1.obj
# |     mesh {'name': 'fridge_main_group_model_1_vis', 'file': '../kitchen_dataset/../fixtures/fridges/pack_2/visuals/model_1.obj', 'scale': '1.75 1.75 1.75'}
# ../fixtures/microwaves/gray/visuals/model_0.obj
# |     mesh {'name': 'microwave_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/microwaves/gray/visuals/model_0.obj', 'scale': '0.783513 0.927835 0.783513'}
# ../fixtures/microwaves/gray/visuals/door_0.obj
# |     mesh {'name': 'microwave_main_group_door_0_vis', 'file': '../kitchen_dataset/../fixtures/microwaves/gray/visuals/door_0.obj', 'scale': '0.783513 0.927835 0.783513'}
# ../fixtures/dishwashers/pack_2/visuals/model_0.obj
# |     mesh {'name': 'dishwasher_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/dishwashers/pack_2/visuals/model_0.obj', 'scale': '0.907083 0.760316 0.89'}
# ../fixtures/dishwashers/pack_2/visuals/model_1.obj
# |     mesh {'name': 'dishwasher_main_group_model_1_vis', 'file': '../kitchen_dataset/../fixtures/dishwashers/pack_2/visuals/model_1.obj', 'scale': '0.907083 0.760316 0.89'}
# ../fixtures/coffee_machines/nespresso/visuals/model_0.obj
# |     mesh {'name': 'coffee_machine_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_0.obj', 'scale': '0.423992 0.423992 0.423992'}
# ../fixtures/coffee_machines/nespresso/visuals/model_1.obj
# |     mesh {'name': 'coffee_machine_main_group_model_1_vis', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_1.obj', 'scale': '0.423992 0.423992 0.423992'}
# ../fixtures/coffee_machines/nespresso/visuals/model_2.obj
# |     mesh {'name': 'coffee_machine_main_group_model_2_vis', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_2.obj', 'scale': '0.423992 0.423992 0.423992'}
# ../fixtures/coffee_machines/nespresso/visuals/model_3.obj
# |     mesh {'name': 'coffee_machine_main_group_model_3_vis', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_3.obj', 'scale': '0.423992 0.423992 0.423992'}
# ../fixtures/coffee_machines/nespresso/visuals/model_4.obj
# |     mesh {'name': 'coffee_machine_main_group_model_4_vis', 'file': '../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_4.obj', 'scale': '0.423992 0.423992 0.423992'}
# ../fixtures/toasters/basic_popup_2/visuals/model_0.obj
# |     mesh {'name': 'toaster_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/model_0.obj', 'scale': '0.3 0.3 0.3'}
# ../fixtures/toasters/basic_popup_2/visuals/model_1.obj
# |     mesh {'name': 'toaster_main_group_model_1_vis', 'file': '../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/model_1.obj', 'scale': '0.3 0.3 0.3'}
# ../fixtures/accessories/knife_blocks/light_wood_3/visuals/model_0.obj
# |     mesh {'name': 'knife_block_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/accessories/knife_blocks/light_wood_3/visuals/model_0.obj', 'scale': '0.381892 0.381892 0.381892'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_0.obj
# |     mesh {'name': 'paper_towel_main_group_model_0_vis', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_0.obj', 'scale': '0.35 0.35 0.35'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_1.obj
# |     mesh {'name': 'paper_towel_main_group_model_1_vis', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_1.obj', 'scale': '0.35 0.35 0.35'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_2.obj
# |     mesh {'name': 'paper_towel_main_group_model_2_vis', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_2.obj', 'scale': '0.35 0.35 0.35'}
# ../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_3.obj
# |     mesh {'name': 'paper_towel_main_group_model_3_vis', 'file': '../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_3.obj', 'scale': '0.35 0.35 0.35'}
# |   worldbody {}
# |     light {'pos': '2 -2 2', 'dir': '0.009999 0.009999 -0.9999', 'directional': 'true', 'castshadow': 'false', 'ambient': '0.3 0.3 0.3', 'diffuse': '0.3 0.3 0.3'}
# |     body {'name': 'left_eef_target', 'pos': '0 0 -1', 'mocap': 'true'}
# |       geom {'name': 'left_eef_target_box', 'size': '0.05 0.05 0.05', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '2', 'rgba': '0.898 0.42 0.435 0.5'}
# |       geom {'name': 'left_eef_target_sphere', 'size': '0.01', 'contype': '0', 'conaffinity': '0', 'group': '2', 'rgba': '0.898 0.42 0.435 0.8'}
# |     body {'name': 'right_eef_target', 'pos': '0 0 -1', 'mocap': 'true'}
# |       geom {'name': 'right_eef_target_box', 'size': '0.05 0.05 0.05', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '2', 'rgba': '0.208 0.314 0.439 0.5'}
# |       geom {'name': 'right_eef_target_sphere', 'size': '0.01', 'contype': '0', 'conaffinity': '0', 'group': '2', 'rgba': '0.208 0.314 0.439 0.8'}
# |     body {'name': 'wall_room_main', 'pos': '2.75 0.02 1.5', 'quat': '-0.707107 0.707107 0 0'}
# |       geom {'name': 'wall_room_g0', 'size': '2.79 1.5 0.02', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'wall_room_g0_vis', 'size': '2.79 1.5 0.02', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'wall_room_wall_mat'}
# |       site {'name': 'wall_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'wall_backing_room_main', 'pos': '2.75 0.14 1.38', 'quat': '-0.707107 0.707107 0 0'}
# |       geom {'name': 'wall_backing_room_g0', 'size': '2.99 1.62 0.1', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'wall_backing_room_g0_vis', 'size': '2.99 1.62 0.1', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'wall_backing_room_wall_mat'}
# |       site {'name': 'wall_backing_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'wall_left_room_main', 'pos': '-0.02 -1.5 1.5', 'quat': '0.5 0.5 -0.5 -0.5'}
# |       geom {'name': 'wall_left_room_g0', 'size': '1.54 1.5 0.02', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'wall_left_room_g0_vis', 'size': '1.54 1.5 0.02', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'wall_left_room_wall_mat'}
# |       site {'name': 'wall_left_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'wall_left_backing_room_main', 'pos': '-0.14 -1.5 1.38', 'quat': '0.5 0.5 -0.5 -0.5'}
# |       geom {'name': 'wall_left_backing_room_g0', 'size': '1.54 1.62 0.1', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'wall_left_backing_room_g0_vis', 'size': '1.54 1.62 0.1', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'wall_left_backing_room_wall_mat'}
# |       site {'name': 'wall_left_backing_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'wall_right_room_main', 'pos': '5.52 -1.5 1.5', 'quat': '0.5 -0.5 -0.5 0.5'}
# |       geom {'name': 'wall_right_room_g0', 'size': '1.54 1.5 0.02', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'wall_right_room_g0_vis', 'size': '1.54 1.5 0.02', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'wall_right_room_wall_mat'}
# |       site {'name': 'wall_right_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'wall_right_backing_room_main', 'pos': '5.64 -1.5 1.38', 'quat': '0.5 -0.5 -0.5 0.5'}
# |       geom {'name': 'wall_right_backing_room_g0', 'size': '1.54 1.62 0.1', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'wall_right_backing_room_g0_vis', 'size': '1.54 1.62 0.1', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'wall_right_backing_room_wall_mat'}
# |       site {'name': 'wall_right_backing_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'floor_room_main', 'pos': '2.75 -1.5 -0.02', 'quat': '0.707107 0 0 0.707107'}
# |       geom {'name': 'floor_room_g0', 'size': '1.54 2.79 0.02', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'floor_room_g0_vis', 'size': '1.54 2.79 0.02', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'floor_room_wall_mat'}
# |       site {'name': 'floor_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'floor_backing_room_main', 'pos': '2.75 -1.5 -0.14', 'quat': '0.707107 0 0 0.707107'}
# |       geom {'name': 'floor_backing_room_g0', 'size': '1.54 2.79 0.1', 'type': 'box', 'rgba': '0.5 0 0 1'}
# |       geom {'name': 'floor_backing_room_g0_vis', 'size': '1.54 2.79 0.1', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'floor_backing_room_wall_mat'}
# |       site {'name': 'floor_backing_room_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 -1'}
# |     body {'name': 'outlet_room_main', 'pos': '4.1 0 1.2'}
# === file:  ../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj
# Converted ../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/material_0.png to outlet_room_outlet_0_vis
# |       geom {'name': 'outlet_room_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'outlet_room_outlet', 'mesh': 'outlet_room_outlet_0_vis'}
# |       site {'name': 'outlet_room_default_site', 'pos': '0 0 0', 'size': '0.0003', 'rgba': '1 0 0 0'}
# |     body {'name': 'outlet_2_room_main', 'pos': '2 0 1.2'}
# === file:  ../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj
# Converted ../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/outlet_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/accessories/outlets/simple_white/visuals/material_0.png to outlet_2_room_outlet_0_vis
# |       geom {'name': 'outlet_2_room_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'outlet_2_room_outlet', 'mesh': 'outlet_2_room_outlet_0_vis'}
# |       site {'name': 'outlet_2_room_default_site', 'pos': '0 0 0', 'size': '0.0003', 'rgba': '1 0 0 0'}
# |     body {'name': 'light_switch_room_main', 'pos': '2.5 0 1.2', 'quat': '0.707388 0 0 -0.706825'}
# === file:  ../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj
# Converted ../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/image0.png to light_switch_room_light_switch_0_vis
# |       geom {'name': 'light_switch_room_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'light_switch_room_lightswitch', 'mesh': 'light_switch_room_light_switch_0_vis'}
# |       site {'name': 'light_switch_room_default_site', 'pos': '0 0 0', 'size': '0.0003', 'rgba': '1 0 0 0'}
# |     body {'name': 'light_switch_2_room_main', 'pos': '2.61 0 1.2', 'quat': '0.707388 0 0 -0.706825'}
# === file:  ../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj
# Converted ../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/light_switch_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/accessories/light_switches/white_wide_switch/visuals/image0.png to light_switch_2_room_light_switch_0_vis
# |       geom {'name': 'light_switch_2_room_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'light_switch_2_room_lightswitch', 'mesh': 'light_switch_2_room_light_switch_0_vis'}
# |       site {'name': 'light_switch_2_room_default_site', 'pos': '0 0 0', 'size': '0.0003', 'rgba': '1 0 0 0'}
# |     body {'name': 'sink_main_group_main', 'pos': '1.25 -0.3 0.96125'}
# === file:  ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/model_0.obj
# Converted ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/model_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/image0.png to sink_main_group_model_0_vis
# |       geom {'name': 'sink_main_group_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'sink_main_group_m_sink', 'mesh': 'sink_main_group_model_0_vis'}
# |       geom {'name': 'sink_main_group_bottom', 'size': '0.183333 0.22 0.0114583', 'pos': '0.22 0 -0.238333', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g2', 'size': '0.0114583 0.22 0.0916667', 'pos': '0.0229167 0 -0.1375', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g3', 'size': '0.0275 0.275 0.0348333', 'pos': '0.430833 0 -0.0733333', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g4', 'size': '0.0275 0.238333 0.0916667', 'pos': '0.430833 0 -0.1925', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g5', 'size': '0.201667 0.00916667 0.1265', 'pos': '0.22 -0.23375 -0.165', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g6', 'size': '0.201667 0.0275 0.0531667', 'pos': '0.22 -0.252083 -0.0916667', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g7', 'size': '0.183333 0.0275 0.1265', 'pos': '0.22 0.249333 -0.165', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g8', 'size': '0.238333 0.275 0.099', 'pos': '-0.210833 0 -0.1375', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'sink_main_group_g9', 'size': '0.0320833 0.055', 'pos': '-0.00916667 0.224583 0.00916667', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |       site {'name': 'sink_main_group_ext_p0', 'pos': '-0.458333 -0.275 -0.28875', 'size': '0.00458333', 'rgba': '1 1 1 0'}
# |       site {'name': 'sink_main_group_ext_px', 'pos': '0.458333 -0.275 -0.28875', 'size': '0.00458333', 'rgba': '1 0 0 0'}
# |       site {'name': 'sink_main_group_ext_py', 'pos': '-0.458333 0.275 -0.28875', 'size': '0.00458333', 'rgba': '0 1 0 0'}
# |       site {'name': 'sink_main_group_ext_pz', 'pos': '-0.458333 -0.275 -0.04125', 'size': '0.00458333', 'rgba': '0 0 1 0'}
# |       site {'name': 'sink_main_group_int_p0', 'pos': '0.0366667 -0.22 -0.238333', 'size': '0.00458333', 'rgba': '0.5 0.5 0.5 0'}
# |       site {'name': 'sink_main_group_int_px', 'pos': '0.403333 -0.22 -0.238333', 'size': '0.00458333', 'rgba': '1 1 0 0'}
# |       site {'name': 'sink_main_group_int_py', 'pos': '0.0366667 0.22 -0.238333', 'size': '0.00458333', 'rgba': '0 1 1 0'}
# |       site {'name': 'sink_main_group_int_pz', 'pos': '0.0366667 -0.22 -0.0458333', 'size': '0.00458333', 'rgba': '1 0 1 0'}
# |       site {'name': 'sink_main_group_default_site', 'pos': '0 0 0', 'size': '0.00183333', 'rgba': '1 0 0 0'}
# |       body {'name': 'sink_main_group_spout'}
# === file:  ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/spout_0.obj
# Converted ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/spout_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/image0.png to sink_main_group_spout_0_vis
# |         joint {'name': 'sink_main_group_spout_joint', 'pos': '-0.00825 0.2255 0.146667', 'axis': '0 0 1', 'damping': '10'}
# |         geom {'name': 'sink_main_group_g10', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'sink_main_group_m_sink', 'mesh': 'sink_main_group_spout_0_vis'}
# |         geom {'name': 'sink_main_group_g11', 'size': '0.0183333 0.0733333', 'pos': '-0.00825 0.2255 0.146667', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |         geom {'name': 'sink_main_group_g12', 'size': '0.0183333 0.0366667', 'pos': '0.00458333 0.210833 0.256667', 'quat': '0.884043 0.365976 0.268631 0.111208', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |         geom {'name': 'sink_main_group_spout_top', 'size': '0.0183333 0.06875', 'pos': '0.0825 0.1375 0.275', 'quat': '0.653595 0.653075 0.270576 0.27036', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |         geom {'name': 'sink_main_group_g14', 'size': '0.0183333 0.0366667', 'pos': '0.1375 0.0825 0.2475', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |         site {'name': 'sink_main_group_water', 'pos': '0.142083 0.0825 0', 'size': '0.00916667 0.229167', 'type': 'cylinder', 'rgba': '0.5 0.75 1 0'}
# |       body {'name': 'sink_main_group_handle'}
# === file:  ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/handle_0.obj
# Converted ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/handle_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/sinks/concrete_sink/visuals/image0.png to sink_main_group_handle_0_vis
# |         joint {'name': 'sink_main_group_handle_joint', 'pos': '0.055 0.2255 0.0366667', 'axis': '0 1 0', 'range': '0 0.52', 'damping': '10'}
# |         joint {'name': 'sink_main_group_handle_temp_joint', 'pos': '0.055 0.2255 0.0155833', 'axis': '1 0 0', 'range': '-0.785 0.785', 'damping': '50'}
# |         geom {'name': 'sink_main_group_g15', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'sink_main_group_m_sink', 'mesh': 'sink_main_group_handle_0_vis'}
# |         geom {'name': 'sink_main_group_g16', 'size': '0.01375 0.0275 0.0275', 'pos': '0.06875 0.2255 0.0155833', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |         geom {'name': 'sink_main_group_handle_main', 'size': '0.00916667 0.0275', 'pos': '0.0733333 0.2255 0.0733333', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |     body {'name': 'counter_main_main_group_main', 'pos': '1.5 -0.325 0.46'}
# |       geom {'name': 'counter_main_main_group_base_right', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'density': '10', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_left', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'density': '10', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_back', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'density': '10', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_front', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'density': '10', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_right_visual', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'counter_main_main_group_counter_base', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_left_visual', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'counter_main_main_group_counter_base', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_back_visual', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'counter_main_main_group_counter_base', 'rgba': '0 0 0 0'}
# |       geom {'name': 'counter_main_main_group_base_front_visual', 'size': '0.01 0.01 0.01', 'pos': '0 0 10', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'counter_main_main_group_counter_base', 'rgba': '0 0 0 0'}
# ...
# |       site {'name': 'stack_4_main_group_2_ext_py', 'pos': '-0.35 0.3 -0.105', 'rgba': '0 1 0 0'}
# |       site {'name': 'stack_4_main_group_2_ext_pz', 'pos': '-0.35 -0.3 0.105', 'rgba': '0 0 1 0'}
# |       site {'name': 'stack_4_main_group_2_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 0'}
# |       body {'name': 'stack_4_main_group_2_inner_box'}
# |         joint {'name': 'stack_4_main_group_2_slidejoint', 'pos': '0 -0.3 0', 'axis': '0 1 0', 'type': 'slide', 'limited': 'true', 'range': '-0.6 0', 'damping': '10'}
# |         geom {'name': 'stack_4_main_group_2_inner_bottom', 'size': '0.319 0.27 0.015', 'pos': '0 0 -0.059', 'type': 'box', 'mass': '0.2', 'rgba': '0.5 0 0 1'}
# |         geom {'name': 'stack_4_main_group_2_inner_back', 'size': '0.289 0.015 0.044', 'pos': '0 0.255 0', 'type': 'box', 'mass': '0.2', 'rgba': '0.5 0 0 1'}
# |         geom {'name': 'stack_4_main_group_2_inner_right', 'size': '0.015 0.27 0.044', 'pos': '0.304 0 0', 'type': 'box', 'mass': '0.2', 'rgba': '0.5 0 0 1'}
# |         geom {'name': 'stack_4_main_group_2_inner_left', 'size': '0.015 0.27 0.044', 'pos': '-0.304 0 0', 'type': 'box', 'mass': '0.2', 'rgba': '0.5 0 0 1'}
# |         geom {'name': 'stack_4_main_group_2_inner_bottom_visual', 'size': '0.319 0.27 0.015', 'pos': '0 0 -0.059', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_mat'}
# |         geom {'name': 'stack_4_main_group_2_inner_back_visual', 'size': '0.289 0.015 0.044', 'pos': '0 0.255 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_mat'}
# |         geom {'name': 'stack_4_main_group_2_inner_right_visual', 'size': '0.015 0.27 0.044', 'pos': '0.304 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_mat'}
# |         geom {'name': 'stack_4_main_group_2_inner_left_visual', 'size': '0.015 0.27 0.044', 'pos': '-0.304 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_mat'}
# |         site {'name': 'stack_4_main_group_2_int_p0', 'pos': '-0.289 -0.27 -0.044', 'rgba': '0.5 0.5 0.5 0'}
# |         site {'name': 'stack_4_main_group_2_int_px', 'pos': '0.289 -0.27 -0.044', 'rgba': '1 1 0 0'}
# |         site {'name': 'stack_4_main_group_2_int_py', 'pos': '-0.289 0.24 -0.044', 'rgba': '0 1 1 0'}
# |         site {'name': 'stack_4_main_group_2_int_pz', 'pos': '-0.289 -0.27 0.074', 'rgba': '1 0 1 0'}
# |         body {'name': 'stack_4_main_group_2_door_main', 'pos': '0 -0.285 0'}
# |           geom {'name': 'stack_4_main_group_2_door_door', 'size': '0.2685 0.0235 0.005', 'pos': '0 0.005 0', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'density': '10', 'rgba': '0.5 0 0 1'}
# |           geom {'name': 'stack_4_main_group_2_door_door_visual', 'size': '0.2685 0.0235 0.005', 'pos': '0 0.005 0', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_mat'}
# |           site {'name': 'stack_4_main_group_2_door_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 0'}
# |           body {'name': 'stack_4_main_group_2_door_trims'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_top', 'size': '0.2685 0.04 0.01', 'pos': '0 -0.0025 0.0635', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_bottom', 'size': '0.2685 0.04 0.01', 'pos': '0 -0.0025 -0.0635', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_left', 'size': '0.04 0.1035 0.01', 'pos': '-0.3085 -0.0025 0', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_right', 'size': '0.04 0.1035 0.01', 'pos': '0.3085 -0.0025 0', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_top_visual', 'size': '0.2685 0.04 0.01', 'pos': '0 -0.0025 0.0635', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_mat'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_bottom_visual', 'size': '0.2685 0.04 0.01', 'pos': '0 -0.0025 -0.0635', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_mat'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_left_visual', 'size': '0.04 0.1035 0.01', 'pos': '-0.3085 -0.0025 0', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_mat'}
# |             geom {'name': 'stack_4_main_group_2_door_trim_right_visual', 'size': '0.04 0.1035 0.01', 'pos': '0.3085 -0.0025 0', 'quat': '0.707105 0.707108 0 0', 'type': 'box', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_mat'}
# |           body {'name': 'stack_4_main_group_2_door_handle_main'}
# |             geom {'name': 'stack_4_main_group_2_door_handle_handle', 'size': '0.013 0.0635', 'pos': '0 -0.05 0', 'quat': '0.707105 0 0.707108 0', 'type': 'cylinder', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_handle_handle_connector_top', 'size': '0.008 0.025', 'pos': '0.0381 -0.025 0', 'quat': '0.707107 0.707107 0 0', 'type': 'cylinder', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_handle_handle_connector_bottom', 'size': '0.008 0.025', 'pos': '-0.0381 -0.025 0', 'quat': '0.707107 0.707107 0 0', 'type': 'cylinder', 'density': '10', 'rgba': '0.5 0 0 1'}
# |             geom {'name': 'stack_4_main_group_2_door_handle_handle_visual', 'size': '0.013 0.0635', 'pos': '0 -0.05 0', 'quat': '0.707105 0 0.707108 0', 'type': 'cylinder', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_handle_mat'}
# |             geom {'name': 'stack_4_main_group_2_door_handle_handle_connector_top_visual', 'size': '0.008 0.025', 'pos': '0.0381 -0.025 0', 'quat': '0.707107 0.707107 0 0', 'type': 'cylinder', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_handle_mat'}
# |             geom {'name': 'stack_4_main_group_2_door_handle_handle_connector_bottom_visual', 'size': '0.008 0.025', 'pos': '-0.0381 -0.025 0', 'quat': '0.707107 0.707107 0 0', 'type': 'cylinder', 'contype': '0', 'conaffinity': '0', 'group': '1', 'mass': '0', 'material': 'stack_4_main_group_2_door_handle_mat'}
# |             site {'name': 'stack_4_main_group_2_door_handle_default_site', 'pos': '0 0 0', 'size': '0.002', 'rgba': '1 0 0 0'}
# |     body {'name': 'coffee_machine_main_group_main', 'pos': '0.322609 -0.212016 1.075'}
# Assigned texture  to coffee_machine_main_group_model_0_vis
# Assigned texture 0.15482 0.15482 0.15482 1 to coffee_machine_main_group_model_1_vis
# Assigned texture  to coffee_machine_main_group_model_2_vis
# === file:  ../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_3.obj
# -- WARNING:assimpInterface.cpp:loadMesh:210(-1) no texture could be loaded
# Converted ../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/model_3.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/coffee_machines/nespresso/visuals/image0.png to coffee_machine_main_group_model_3_vis
# -- WARNING:assimpInterface.cpp:loadMesh:210(-1) no texture could be loaded
# Assigned texture 0.8 0.686012 0.55947 1 to coffee_machine_main_group_model_4_vis
# |       geom {'name': 'coffee_machine_main_group_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'coffee_machine_main_group_Water', 'mesh': 'coffee_machine_main_group_model_0_vis'}
# |       geom {'name': 'coffee_machine_main_group_g1', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'coffee_machine_main_group_Perspex', 'mesh': 'coffee_machine_main_group_model_1_vis'}
# |       geom {'name': 'coffee_machine_main_group_g2', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'coffee_machine_main_group_Chrome', 'mesh': 'coffee_machine_main_group_model_2_vis'}
# |       geom {'name': 'coffee_machine_main_group_g3', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'coffee_machine_main_group_Black_Plastic', 'mesh': 'coffee_machine_main_group_model_3_vis'}
# |       geom {'name': 'coffee_machine_main_group_g4', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'coffee_machine_main_group_White_Plastic', 'mesh': 'coffee_machine_main_group_model_4_vis'}
# |       geom {'name': 'coffee_machine_main_group_g5', 'size': '0.0466391 0.165357 0.148397', 'pos': '0 0.0466391 -0.0127198', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'coffee_machine_main_group_g6', 'size': '0.0695347 0.0593589', 'pos': '0 -0.0886144 0.0932783', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'coffee_machine_main_group_g7', 'size': '0.0462152 0.0135678', 'pos': '0 -0.165781 -0.0898864', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |       geom {'name': 'coffee_machine_main_group_start_button', 'size': '0.0317994 0.00211996', 'pos': '0 -0.0881904 0.157725', 'type': 'cylinder', 'rgba': '0.5 0 0 0.5'}
# |       site {'name': 'coffee_machine_main_group_receptacle_place_site', 'pos': '0 -0.165781 -0.0763186', 'size': '0.00423992', 'rgba': '0 0 0 -1'}
# |       site {'name': 'coffee_machine_main_group_coffee_liquid', 'pos': '0 -0.148397 -0.0211996', 'size': '0.00254395 0.0635988', 'type': 'cylinder', 'rgba': '0.8 0.5 0.25 0'}
# |       site {'name': 'coffee_machine_main_group_default_site', 'pos': '0 0 0', 'size': '0.000847984', 'rgba': '1 0 0 0'}
# |     body {'name': 'toaster_main_group_main', 'pos': '3.98294 -0.204428 0.999275'}
# === file:  ../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/model_0.obj
# Converted ../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/model_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/image3.png to toaster_main_group_model_0_vis
# === file:  ../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/model_1.obj
# Converted ../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/model_1.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/toasters/basic_popup_2/visuals/image0.png to toaster_main_group_model_1_vis
# |       geom {'name': 'toaster_main_group_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'toaster_main_group_Material_39', 'mesh': 'toaster_main_group_model_0_vis'}
# |       geom {'name': 'toaster_main_group_g1', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'toaster_main_group_Material_38', 'mesh': 'toaster_main_group_model_1_vis'}
# |       geom {'name': 'toaster_main_group_g2', 'size': '0.0866399 0.15 0.0792752', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       site {'name': 'toaster_main_group_default_site', 'pos': '0 0 0', 'size': '0.0006', 'rgba': '1 0 0 0'}
# |     body {'name': 'knife_block_main_group_main', 'pos': '2.42657 -0.103333 1.11095'}
# === file:  ../kitchen_dataset/../fixtures/accessories/knife_blocks/light_wood_3/visuals/model_0.obj
# Converted ../kitchen_dataset/../fixtures/accessories/knife_blocks/light_wood_3/visuals/model_0.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/accessories/knife_blocks/light_wood_3/visuals/image0.png to knife_block_main_group_model_0_vis
# |       geom {'name': 'knife_block_main_group_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'knife_block_main_group_Knife_rack', 'mesh': 'knife_block_main_group_model_0_vis'}
# |       geom {'name': 'knife_block_main_group_g1', 'size': '0.06 0.0793856 0.190946', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       site {'name': 'knife_block_main_group_default_site', 'pos': '0 0 0', 'size': '0.000763785', 'rgba': '1 0 0 0'}
# |     body {'name': 'paper_towel_main_group_main', 'pos': '2.18551 -0.149973 1.095'}
# Assigned texture 0.327778 0.266356 0.198069 1 to paper_towel_main_group_model_0_vis
# === file:  ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_1.obj
# -- WARNING:assimpInterface.cpp:loadMesh:210(-1) no texture could be loaded
# Converted ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_1.obj
# === file:  tmp.ply
# Assigned texture ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/image1.png to paper_towel_main_group_model_1_vis
# === file:  ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_2.obj
# ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/image0.png is not a valid texture path or could not be applied to the mesh. index 639 is out of bounds for axis 0 with size 512
# Converted ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/model_2.obj
# === file:  tmp.ply
# no colors for: tmp
# Assigned texture ../kitchen_dataset/../fixtures/accessories/paper_towel_holders/holder_2/visuals/image0.png to paper_towel_main_group_model_2_vis
# Assigned texture 0.35595 0.35595 0.35595 1 to paper_towel_main_group_model_3_vis
# |       geom {'name': 'paper_towel_main_group_g0', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'paper_towel_main_group_paperboard', 'mesh': 'paper_towel_main_group_model_0_vis'}
# |       geom {'name': 'paper_towel_main_group_g1', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'paper_towel_main_group_paperTopAndBottom', 'mesh': 'paper_towel_main_group_model_1_vis'}
# |       geom {'name': 'paper_towel_main_group_g2', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'paper_towel_main_group_paperSide', 'mesh': 'paper_towel_main_group_model_2_vis'}
# |       geom {'name': 'paper_towel_main_group_g3', 'type': 'mesh', 'contype': '0', 'conaffinity': '0', 'group': '1', 'friction': '0.95 0.3 0.1', 'solref': '0.001', 'solimp': '0.998 0.998', 'density': '100', 'material': 'paper_towel_main_group_metal', 'mesh': 'paper_towel_main_group_model_3_vis'}
# |       geom {'name': 'paper_towel_main_group_g4', 'size': '0.0959265 0.0959265 0.175', 'type': 'box', 'rgba': '0.5 0 0 0.5'}
# |       site {'name': 'paper_towel_main_group_default_site', 'pos': '0 0 0', 'size': '0.0007', 'rgba': '1 0 0 0'}
# |   actuator {}
# |   sensor {}
# loaded #frames:  494
# -- WARNING:assimpInterface.cpp:loadMesh:210(-1) no texture could be loaded
# simplified #frames:  357

# %% [markdown]
# ## Generate KOMO texts

# %%
frame_names = C.getFrameNames()

# Special Features (for random manipulation KOMOs)
end_effector_frames = ["r_gripper", "l_gripper"]
mobile_base_frames = ["omnibase"]
# object_frames = ["kebabs_8", "can_6", "pizza_cutter_2", "bell_pepper_0", "kebabs_13"]  # Frames that are not attached to anything that can be manipulated with basic pick, place, push, etc.
joint_frames = [fn for fn in frame_names if fn.endswith("hinge") or fn.endswith("_slidejoint")]
jointed_frames = [fn for fn in frame_names if fn.endswith("_handle_handle_visual")]
world_attach_frames = ["omnibase_world"]  # Like table in manipulation.py, some sort of world frame that tells us the world rotation and for us to place stuff after a mode switch.

for f in frame_names:
    print(f)
print(len(joint_frames))
print(len(jointed_frames))
# Out:
# base
# wall_room_g0_vis
# wall_backing_room_g0_vis
# wall_left_room_g0_vis
# wall_left_backing_room_g0_vis
# wall_right_room_g0_vis
# wall_right_backing_room_g0_vis
# floor_room_g0_vis
# floor_backing_room_g0_vis
# outlet_room_g0
# outlet_2_room_g0
# light_switch_room_g0
# light_switch_2_room_g0
# sink_main_group_g0
# sink_main_group_spout_joint_origin
# sink_main_group_spout_joint
# sink_main_group_g10
# sink_main_group_handle_joint_origin
# sink_main_group_handle_joint
# sink_main_group_handle_temp_joint_origin
# sink_main_group_handle_temp_joint
# sink_main_group_g15
# counter_main_main_group_base_right_visual
# counter_main_main_group_base_left_visual
# counter_main_main_group_base_back_visual
# counter_main_main_group_base_front_visual
# counter_main_main_group_top_left_visual
# counter_main_main_group_top_right_visual
# counter_main_main_group_top_front_visual
# counter_main_main_group_top_back_visual
# stove_main_group_g0
# stove_main_group_g1
# stove_main_group_knob_rear_right_joint_origin
# stove_main_group_knob_rear_right_joint
# stove_main_group_g6
# stove_main_group_knob_dummy_joint_origin
# stove_main_group_knob_dummy_joint
# stove_main_group_g8
# stove_main_group_knob_front_left_joint_origin
# stove_main_group_knob_front_left_joint
# stove_main_group_g10
# stove_main_group_knob_front_right_joint_origin
# stove_main_group_knob_front_right_joint
# stove_main_group_g12
# stove_main_group_knob_rear_left_joint_origin
# stove_main_group_knob_rear_left_joint
# stove_main_group_g14
# counter_right_main_group_base_right_visual
# counter_right_main_group_base_left_visual
# counter_right_main_group_base_back_visual
# counter_right_main_group_base_front_visual
# counter_right_main_group_top_visual
# fridge_main_group_g0
# fridge_main_group_g1
# fridge_housing_main_group_top_visual
# fridge_housing_main_group_back_visual
# fridge_housing_main_group_left_visual
# fridge_housing_main_group_right_visual
# cab_1_main_group_top_visual
# cab_1_main_group_bottom_visual
# cab_1_main_group_back_visual
# cab_1_main_group_right_visual
# cab_1_main_group_left_visual
# cab_1_main_group_shelf_visual
# cab_1_main_group_doorhinge_origin
# cab_1_main_group_doorhinge
# cab_1_main_group_door_door_visual
# cab_1_main_group_door_trim_top_visual
# cab_1_main_group_door_trim_bottom_visual
# cab_1_main_group_door_trim_left_visual
# cab_1_main_group_door_trim_right_visual
# cab_1_main_group_door_handle_handle_visual
# cab_1_main_group_door_handle_handle_connector_top_visual
# cab_1_main_group_door_handle_handle_connector_bottom_visual
# cab_2_main_group_top_visual
# cab_2_main_group_bottom_visual
# cab_2_main_group_back_visual
# cab_2_main_group_right_visual
# cab_2_main_group_left_visual
# cab_2_main_group_shelf_visual
# cab_2_main_group_leftdoorhinge_origin
# cab_2_main_group_leftdoorhinge
# cab_2_main_group_left_door_door_visual
# cab_2_main_group_left_door_trim_top_visual
# cab_2_main_group_left_door_trim_bottom_visual
# cab_2_main_group_left_door_trim_left_visual
# cab_2_main_group_left_door_trim_right_visual
# cab_2_main_group_left_door_handle_handle_visual
# cab_2_main_group_left_door_handle_handle_connector_top_visual
# cab_2_main_group_left_door_handle_handle_connector_bottom_visual
# cab_2_main_group_rightdoorhinge_origin
# cab_2_main_group_rightdoorhinge
# cab_2_main_group_right_door_door_visual
# cab_2_main_group_right_door_trim_top_visual
# cab_2_main_group_right_door_trim_bottom_visual
# cab_2_main_group_right_door_trim_left_visual
# cab_2_main_group_right_door_trim_right_visual
# cab_2_main_group_right_door_handle_handle_visual
# cab_2_main_group_right_door_handle_handle_connector_top_visual
# cab_2_main_group_right_door_handle_handle_connector_bottom_visual
# cab_main_main_group_top_visual
# cab_main_main_group_bottom_visual
# cab_main_main_group_back_visual
# cab_main_main_group_right_visual
# cab_main_main_group_left_visual
# cab_main_main_group_shelf_visual
# cab_main_main_group_leftdoorhinge_origin
# cab_main_main_group_leftdoorhinge
# cab_main_main_group_left_door_door_visual
# cab_main_main_group_left_door_trim_top_visual
# cab_main_main_group_left_door_trim_bottom_visual
# cab_main_main_group_left_door_trim_left_visual
# cab_main_main_group_left_door_trim_right_visual
# cab_main_main_group_left_door_handle_handle_visual
# cab_main_main_group_left_door_handle_handle_connector_top_visual
# cab_main_main_group_left_door_handle_handle_connector_bottom_visual
# cab_main_main_group_rightdoorhinge_origin
# cab_main_main_group_rightdoorhinge
# cab_main_main_group_right_door_door_visual
# cab_main_main_group_right_door_trim_top_visual
# cab_main_main_group_right_door_trim_bottom_visual
# cab_main_main_group_right_door_trim_left_visual
# cab_main_main_group_right_door_trim_right_visual
# cab_main_main_group_right_door_handle_handle_visual
# cab_main_main_group_right_door_handle_handle_connector_top_visual
# cab_main_main_group_right_door_handle_handle_connector_bottom_visual
# microwave_main_group_g0
# microwave_main_group_g13
# microwave_main_group_g14
# microwave_main_group_microjoint_origin
# microwave_main_group_microjoint
# microwave_main_group_g15
# microwave_main_group_g20
# microwave_main_group_g21
# microwave_main_group_g22
# microwave_main_group_g23
# cab_micro_main_group_top_visual
# cab_micro_main_group_bottom_visual
# cab_micro_main_group_back_visual
# cab_micro_main_group_right_visual
# cab_micro_main_group_left_visual
# cab_micro_main_group_shelf_visual
# cab_micro_main_group_leftdoorhinge_origin
# cab_micro_main_group_leftdoorhinge
# cab_micro_main_group_left_door_door_visual
# cab_micro_main_group_left_door_trim_top_visual
# cab_micro_main_group_left_door_trim_bottom_visual
# cab_micro_main_group_left_door_trim_left_visual
# cab_micro_main_group_left_door_trim_right_visual
# cab_micro_main_group_left_door_handle_handle_visual
# cab_micro_main_group_rightdoorhinge_origin
# cab_micro_main_group_rightdoorhinge
# cab_micro_main_group_right_door_door_visual
# cab_micro_main_group_right_door_trim_top_visual
# cab_micro_main_group_right_door_trim_bottom_visual
# cab_micro_main_group_right_door_trim_left_visual
# cab_micro_main_group_right_door_trim_right_visual
# cab_micro_main_group_right_door_handle_handle_visual
# cab_3_main_group_shelf_0_shelf_visual
# cab_3_main_group_shelf_1_shelf_visual
# cab_3_main_group_shelf_2_shelf_visual
# cab_4_main_group_top_visual
# cab_4_main_group_bottom_visual
# cab_4_main_group_back_visual
# cab_4_main_group_right_visual
# cab_4_main_group_left_visual
# cab_4_main_group_shelf_visual
# cab_4_main_group_leftdoorhinge_origin
# cab_4_main_group_leftdoorhinge
# cab_4_main_group_left_door_door_visual
# cab_4_main_group_left_door_trim_top_visual
# cab_4_main_group_left_door_trim_bottom_visual
# cab_4_main_group_left_door_trim_left_visual
# cab_4_main_group_left_door_trim_right_visual
# cab_4_main_group_left_door_handle_handle_visual
# cab_4_main_group_rightdoorhinge_origin
# cab_4_main_group_rightdoorhinge
# cab_4_main_group_right_door_door_visual
# cab_4_main_group_right_door_trim_top_visual
# cab_4_main_group_right_door_trim_bottom_visual
# cab_4_main_group_right_door_trim_left_visual
# cab_4_main_group_right_door_trim_right_visual
# cab_4_main_group_right_door_handle_handle_visual
# stack_1_main_group_base_g0_vis
# stack_1_main_group_1_top_visual
# stack_1_main_group_1_bottom_visual
# stack_1_main_group_1_back_visual
# stack_1_main_group_1_right_visual
# stack_1_main_group_1_left_visual
# stack_1_main_group_1_slidejoint_origin
# stack_1_main_group_1_slidejoint
# stack_1_main_group_1_inner_bottom_visual
# stack_1_main_group_1_inner_back_visual
# stack_1_main_group_1_inner_right_visual
# stack_1_main_group_1_inner_left_visual
# stack_1_main_group_1_door_door_visual
# stack_1_main_group_1_door_trim_top_visual
# stack_1_main_group_1_door_trim_bottom_visual
# stack_1_main_group_1_door_trim_left_visual
# stack_1_main_group_1_door_trim_right_visual
# stack_1_main_group_1_door_handle_handle_visual
# stack_1_main_group_1_door_handle_handle_connector_top_visual
# stack_1_main_group_1_door_handle_handle_connector_bottom_visual
# stack_1_main_group_2_top_visual
# stack_1_main_group_2_bottom_visual
# stack_1_main_group_2_back_visual
# stack_1_main_group_2_right_visual
# stack_1_main_group_2_left_visual
# stack_1_main_group_2_slidejoint_origin
# stack_1_main_group_2_slidejoint
# stack_1_main_group_2_inner_bottom_visual
# stack_1_main_group_2_inner_back_visual
# stack_1_main_group_2_inner_right_visual
# stack_1_main_group_2_inner_left_visual
# stack_1_main_group_2_door_door_visual
# stack_1_main_group_2_door_trim_top_visual
# stack_1_main_group_2_door_trim_bottom_visual
# stack_1_main_group_2_door_trim_left_visual
# stack_1_main_group_2_door_trim_right_visual
# stack_1_main_group_2_door_handle_handle_visual
# stack_1_main_group_2_door_handle_handle_connector_top_visual
# stack_1_main_group_2_door_handle_handle_connector_bottom_visual
# stack_1_main_group_3_top_visual
# stack_1_main_group_3_bottom_visual
# stack_1_main_group_3_back_visual
# stack_1_main_group_3_right_visual
# stack_1_main_group_3_left_visual
# stack_1_main_group_3_slidejoint_origin
# stack_1_main_group_3_slidejoint
# stack_1_main_group_3_inner_bottom_visual
# stack_1_main_group_3_inner_back_visual
# stack_1_main_group_3_inner_right_visual
# stack_1_main_group_3_inner_left_visual
# stack_1_main_group_3_door_door_visual
# stack_1_main_group_3_door_trim_top_visual
# stack_1_main_group_3_door_trim_bottom_visual
# stack_1_main_group_3_door_trim_left_visual
# stack_1_main_group_3_door_trim_right_visual
# stack_1_main_group_3_door_handle_handle_visual
# stack_1_main_group_3_door_handle_handle_connector_top_visual
# stack_1_main_group_3_door_handle_handle_connector_bottom_visual
# stack_1_main_group_4_top_visual
# stack_1_main_group_4_bottom_visual
# stack_1_main_group_4_back_visual
# stack_1_main_group_4_right_visual
# stack_1_main_group_4_left_visual
# stack_1_main_group_4_slidejoint_origin
# stack_1_main_group_4_slidejoint
# stack_1_main_group_4_inner_bottom_visual
# stack_1_main_group_4_inner_back_visual
# stack_1_main_group_4_inner_right_visual
# stack_1_main_group_4_inner_left_visual
# stack_1_main_group_4_door_door_visual
# stack_1_main_group_4_door_trim_top_visual
# stack_1_main_group_4_door_trim_bottom_visual
# stack_1_main_group_4_door_trim_left_visual
# stack_1_main_group_4_door_trim_right_visual
# stack_1_main_group_4_door_handle_handle_visual
# stack_1_main_group_4_door_handle_handle_connector_top_visual
# stack_1_main_group_4_door_handle_handle_connector_bottom_visual
# stack_2_main_group_base_g0_vis
# stack_2_main_group_1_top_visual
# stack_2_main_group_1_bottom_visual
# stack_2_main_group_1_back_visual
# stack_2_main_group_1_right_visual
# stack_2_main_group_1_left_visual
# stack_2_main_group_1_shelf_visual
# stack_2_main_group_1_leftdoorhinge_origin
# stack_2_main_group_1_leftdoorhinge
# stack_2_main_group_1_left_door_door_visual
# stack_2_main_group_1_left_door_trim_top_visual
# stack_2_main_group_1_left_door_trim_bottom_visual
# stack_2_main_group_1_left_door_trim_left_visual
# stack_2_main_group_1_left_door_trim_right_visual
# stack_2_main_group_1_left_door_handle_handle_visual
# stack_2_main_group_1_left_door_handle_handle_connector_top_visual
# stack_2_main_group_1_left_door_handle_handle_connector_bottom_visual
# stack_2_main_group_1_rightdoorhinge_origin
# stack_2_main_group_1_rightdoorhinge
# stack_2_main_group_1_right_door_door_visual
# stack_2_main_group_1_right_door_trim_top_visual
# stack_2_main_group_1_right_door_trim_bottom_visual
# stack_2_main_group_1_right_door_trim_left_visual
# stack_2_main_group_1_right_door_trim_right_visual
# stack_2_main_group_1_right_door_handle_handle_visual
# stack_2_main_group_1_right_door_handle_handle_connector_top_visual
# stack_2_main_group_1_right_door_handle_handle_connector_bottom_visual
# stack_2_main_group_2_door_door_visual
# stack_2_main_group_2_door_trim_top_visual
# stack_2_main_group_2_door_trim_bottom_visual
# stack_2_main_group_2_door_trim_left_visual
# stack_2_main_group_2_door_trim_right_visual
# dishwasher_main_group_g0
# dishwasher_main_group_g1
# stack_3_main_group_base_g0_vis
# stack_3_main_group_1_top_visual
# stack_3_main_group_1_bottom_visual
# stack_3_main_group_1_back_visual
# stack_3_main_group_1_right_visual
# stack_3_main_group_1_left_visual
# stack_3_main_group_1_shelf_visual
# stack_3_main_group_1_doorhinge_origin
# stack_3_main_group_1_doorhinge
# stack_3_main_group_1_door_door_visual
# stack_3_main_group_1_door_trim_top_visual
# stack_3_main_group_1_door_trim_bottom_visual
# stack_3_main_group_1_door_trim_left_visual
# stack_3_main_group_1_door_trim_right_visual
# stack_3_main_group_1_door_handle_handle_visual
# stack_3_main_group_1_door_handle_handle_connector_top_visual
# stack_3_main_group_1_door_handle_handle_connector_bottom_visual
# stack_4_main_group_base_g0_vis
# stack_4_main_group_1_top_visual
# stack_4_main_group_1_bottom_visual
# stack_4_main_group_1_back_visual
# stack_4_main_group_1_right_visual
# stack_4_main_group_1_left_visual
# stack_4_main_group_1_shelf_visual
# stack_4_main_group_1_doorhinge_origin
# stack_4_main_group_1_doorhinge
# stack_4_main_group_1_door_door_visual
# stack_4_main_group_1_door_trim_top_visual
# stack_4_main_group_1_door_trim_bottom_visual
# stack_4_main_group_1_door_trim_left_visual
# stack_4_main_group_1_door_trim_right_visual
# stack_4_main_group_1_door_handle_handle_visual
# stack_4_main_group_1_door_handle_handle_connector_top_visual
# stack_4_main_group_1_door_handle_handle_connector_bottom_visual
# stack_4_main_group_2_top_visual
# stack_4_main_group_2_bottom_visual
# stack_4_main_group_2_back_visual
# stack_4_main_group_2_right_visual
# stack_4_main_group_2_left_visual
# stack_4_main_group_2_slidejoint_origin
# stack_4_main_group_2_slidejoint
# stack_4_main_group_2_inner_bottom_visual
# stack_4_main_group_2_inner_back_visual
# stack_4_main_group_2_inner_right_visual
# stack_4_main_group_2_inner_left_visual
# stack_4_main_group_2_door_door_visual
# stack_4_main_group_2_door_trim_top_visual
# stack_4_main_group_2_door_trim_bottom_visual
# stack_4_main_group_2_door_trim_left_visual
# stack_4_main_group_2_door_trim_right_visual
# stack_4_main_group_2_door_handle_handle_visual
# stack_4_main_group_2_door_handle_handle_connector_top_visual
# stack_4_main_group_2_door_handle_handle_connector_bottom_visual
# coffee_machine_main_group_g1
# coffee_machine_main_group_g3
# coffee_machine_main_group_g4
# toaster_main_group_g0
# toaster_main_group_g1
# knife_block_main_group_g0
# paper_towel_main_group_g0
# paper_towel_main_group_g1
# paper_towel_main_group_g2
# paper_towel_main_group_g3
# world
# omnibase_world
# omnibase
# omnibase_frame
# omnibase_battery
# omnibase_coll
# r_panda_base
# r_panda_link0
# r_panda_link0_0
# r_panda_joint1_origin
# r_panda_joint1
# r_panda_link1
# r_panda_link1_0
# r_panda_joint2_origin
# r_panda_joint2
# r_panda_link2
# r_panda_link2_0
# r_panda_joint3_origin
# r_panda_joint3
# r_panda_link3
# r_panda_link3_0
# r_panda_joint4_origin
# r_panda_joint4
# r_panda_link4
# r_panda_link4_0
# r_panda_joint5_origin
# r_panda_joint5
# r_panda_link5
# r_panda_link5_0
# r_panda_joint6_origin
# r_panda_joint6
# r_panda_link6
# r_panda_link6_0
# r_panda_joint7_origin
# r_panda_joint7
# r_panda_link7
# r_panda_link7_0
# r_panda_joint8_origin
# r_panda_joint8
# r_panda_link8
# r_panda_hand_joint_origin
# r_panda_hand_joint
# r_panda_hand
# r_panda_hand_0
# r_panda_finger_joint1_origin
# r_panda_finger_joint2_origin
# r_panda_finger_joint1
# r_panda_finger_joint2
# r_panda_leftfinger
# r_panda_rightfinger
# r_panda_leftfinger_0
# r_panda_rightfinger_0
# r_panda_coll0
# r_panda_coll1
# r_panda_coll3
# r_panda_coll5
# r_panda_coll2
# r_panda_coll4
# r_panda_coll6
# r_panda_coll7
# r_gripper
# r_palm
# r_finger1
# r_finger2
# l_panda_base
# l_panda_link0
# l_panda_link0_0
# l_panda_joint1_origin
# l_panda_joint1
# l_panda_link1
# l_panda_link1_0
# l_panda_joint2_origin
# l_panda_joint2
# l_panda_link2
# l_panda_link2_0
# l_panda_joint3_origin
# l_panda_joint3
# l_panda_link3
# l_panda_link3_0
# l_panda_joint4_origin
# l_panda_joint4
# l_panda_link4
# l_panda_link4_0
# l_panda_joint5_origin
# l_panda_joint5
# l_panda_link5
# l_panda_link5_0
# l_panda_joint6_origin
# l_panda_joint6
# l_panda_link6
# l_panda_link6_0
# l_panda_joint7_origin
# l_panda_joint7
# l_panda_link7
# l_panda_link7_0
# l_panda_joint8_origin
# l_panda_joint8
# l_panda_link8
# l_panda_hand_joint_origin
# l_panda_hand_joint
# l_panda_hand
# l_panda_hand_0
# l_panda_finger_joint1_origin
# l_panda_finger_joint2_origin
# l_panda_finger_joint1
# l_panda_finger_joint2
# l_panda_leftfinger
# l_panda_rightfinger
# l_panda_leftfinger_0
# l_panda_rightfinger_0
# l_panda_coll0
# l_panda_coll1
# l_panda_coll3
# l_panda_coll5
# l_panda_coll2
# l_panda_coll4
# l_panda_coll6
# l_panda_coll7
# l_gripper
# l_palm
# l_finger1
# l_finger2
# cameraTop
# cameraWrist
# panda_collCameraWrist
# bellybutton
# 18
# 18

# %%
# komo_generator = lambda: generate_random_komo(frame_names, features, prob_mode_switch=0)
# komo_generator = lambda: generate_random_pick(end_effector_frames,
#                                               object_frames,
#                                               world_attach_frames,
#                                               frame_names,
#                                               drop_prob=0,
#                                               specific_orientation_prob=0,
#                                               hard_grasp_prob=.1,
#                                               specific_place_prob=0,
#                                               place_prob=1,
#                                               endeff_pass_prob=1,
#                                               repeat_pass_prob=1,
#                                               accumulated_collisions=False)
# komo_generator = lambda: generate_random_pivot(end_effector_frames, jointed_frames, joint_frames, slices=8)
def komo_generator():
    # if np.random.random() < .5:
    if np.random.random() < 1.:
        text = generate_random_pivot(end_effector_frames, jointed_frames, joint_frames, slices=1, max_back_and_forth_phases=3)
    else:
        text = generate_random_pick(end_effector_frames,
                                    object_frames,
                                    world_attach_frames,
                                    frame_names,
                                    drop_prob=0,
                                    specific_orientation_prob=.3,
                                    specific_place_prob=.1,
                                    place_prob=1)
    return text

# %%
for i in range(10):
    komo_text = komo_generator()
    print(komo_text)
# Out:
# komo = ry.KOMO(C, 4, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_1_main_group_3_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_1_main_group_3_slidejoint'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_1_main_group_3_slidejoint'], ry.OT.eq, [1e1], [-1.033])
# komo.addObjective([3], ry.FS.qItself, ['stack_1_main_group_3_slidejoint'], ry.OT.eq, [1e1], [1.033])
# komo.addObjective([4], ry.FS.qItself, ['stack_1_main_group_3_slidejoint'], ry.OT.eq, [1e1], [-1.033])
# komo.addObjective([1, 4], ry.FS.negDistance, ['l_gripper', 'stack_1_main_group_3_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.079])
# komo.addObjective([1, 4], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_main_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_main_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_main_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.677])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['r_gripper', 'cab_main_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 4, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_2_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.788])
# komo.addObjective([3], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.788])
# komo.addObjective([4], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.788])
# komo.addObjective([1, 4], ry.FS.negDistance, ['r_gripper', 'cab_2_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.042])
# komo.addObjective([1, 4], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 4, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_2_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.84])
# komo.addObjective([3], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.84])
# komo.addObjective([4], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.84])
# komo.addObjective([1, 4], ry.FS.negDistance, ['r_gripper', 'cab_2_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.061])
# komo.addObjective([1, 4], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 4, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_2_main_group_left_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_2_main_group_leftdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_2_main_group_leftdoorhinge'], ry.OT.eq, [1e1], [-0.622])
# komo.addObjective([3], ry.FS.qItself, ['cab_2_main_group_leftdoorhinge'], ry.OT.eq, [1e1], [0.622])
# komo.addObjective([4], ry.FS.qItself, ['cab_2_main_group_leftdoorhinge'], ry.OT.eq, [1e1], [-0.622])
# komo.addObjective([1, 4], ry.FS.negDistance, ['r_gripper', 'cab_2_main_group_left_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.073])
# komo.addObjective([1, 4], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 4, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_main_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_main_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_main_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.17])
# komo.addObjective([3], ry.FS.qItself, ['cab_main_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.17])
# komo.addObjective([4], ry.FS.qItself, ['cab_main_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.17])
# komo.addObjective([1, 4], ry.FS.negDistance, ['l_gripper', 'cab_main_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.027])
# komo.addObjective([1, 4], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 3, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_2_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.146])
# komo.addObjective([3], ry.FS.qItself, ['cab_2_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.146])
# komo.addObjective([1, 3], ry.FS.negDistance, ['r_gripper', 'cab_2_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.076])
# komo.addObjective([1, 3], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 4, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_micro_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-1.985])
# komo.addObjective([3], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [1.985])
# komo.addObjective([4], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-1.985])
# komo.addObjective([1, 4], ry.FS.negDistance, ['r_gripper', 'cab_micro_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.059])
# komo.addObjective([1, 4], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 3, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['cab_micro_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [-0.208])
# komo.addObjective([3], ry.FS.qItself, ['cab_micro_main_group_rightdoorhinge'], ry.OT.eq, [1e1], [0.208])
# komo.addObjective([1, 3], ry.FS.negDistance, ['r_gripper', 'cab_micro_main_group_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.091])
# komo.addObjective([1, 3], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# komo = ry.KOMO(C, 3, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_4_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [-0.945])
# komo.addObjective([3], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [0.945])
# komo.addObjective([1, 3], ry.FS.negDistance, ['r_gripper', 'stack_4_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1], [0.073])
# komo.addObjective([1, 3], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])

# %%
komo_samples = 10_000

outfolder = "./komo_samples"
text_outfolder = os.path.join(outfolder, "texts")
if not os.path.exists(text_outfolder):
    os.makedirs(text_outfolder)
else:
    for file in os.listdir(text_outfolder):
        file_path = os.path.join(text_outfolder, file)
        os.remove(file_path)

for i in tqdm(range(komo_samples)):
    komo_text = komo_generator()
    filename = os.path.join(text_outfolder, f"komo{i}.txt")
    with open(filename, "w") as file:
        file.write(komo_text)
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 39804.20it/s]

# %% [markdown]
# ## Classify KOMO texts

# %%
total_komos = 0
total_feasible_komos = 0
total_error_komos = 0

feasible_komos = []
error_komos = []

for i in tqdm(range(komo_samples)):
    
    filename = os.path.join(text_outfolder, f"komo{i}.txt")
    with open(filename, "r") as file:
        komo_text = file.read()

    # print(f"Processing file {filename}...")
    total_komos += 1
    
    # try:
    komo = ry.KOMO(C, 1, 1, 0, False)
    exec(komo_text)
    ret = ry.NLP_Solver(komo.nlp(), verbose=0).solve()
    # except:
    #     print(komo_text)
    #     exit()
    #     total_error_komos += 1
    #     error_komos.append(i)
    #     continue
    
    if ret.feasible:
        total_feasible_komos += 1
        feasible_komos.append(i)
    
    if (i+1)%(komo_samples//10) == 0:
        print(f"Total feasible komos: {total_feasible_komos}")
        print(f"Total error komos: {total_error_komos}")
        print(f"Total komos: {total_komos}")
        print(f"{(total_feasible_komos/total_komos)*100:.2f}% feasible")
# Out:
#  10%|▉         | 999/10000 [02:55<30:38,  4.90it/s]
# Total feasible komos: 11
# Total error komos: 0
# Total komos: 1000
# 1.10% feasible
#  20%|██        | 2001/10000 [05:49<18:39,  7.14it/s]
# Total feasible komos: 16
# Total error komos: 0
# Total komos: 2000
# 0.80% feasible
#  30%|███       | 3002/10000 [08:38<15:41,  7.43it/s]
# Total feasible komos: 29
# Total error komos: 0
# Total komos: 3000
# 0.97% feasible
#  40%|████      | 4000/10000 [11:32<16:48,  5.95it/s]
# Total feasible komos: 40
# Total error komos: 0
# Total komos: 4000
# 1.00% feasible
#  50%|█████     | 5000/10000 [14:22<11:24,  7.30it/s]
# Total feasible komos: 58
# Total error komos: 0
# Total komos: 5000
# 1.16% feasible
#  58%|█████▊    | 5830/10000 [16:45<11:59,  5.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 20
#      18 komo = ry.KOMO(C, 1, 1, 0, False)
#      19 exec(komo_text)
# ---> 20 ret = ry.NLP_Solver(komo.nlp(), verbose=0).solve()
#      21 # except:
#      22 #     print(komo_text)
#      23 #     exit()
#      24 #     total_error_komos += 1
#      25 #     error_komos.append(i)
#      26 #     continue
#      28 if ret.feasible:
#
# KeyboardInterrupt:

# %%
result = f"""Total feasible komos - Total error komos - Total komos: 
{total_feasible_komos} - {total_error_komos} - {total_komos}. 
({(total_feasible_komos/total_komos)*100:.2f}% feasible)"""
print(result)
print(feasible_komos)
results_file_path = os.path.join(outfolder, "feasibles.json")
results_dict = {
    "feasible_komos": feasible_komos,
    "error_komos": error_komos,
}
json.dump(results_dict, open(results_file_path, 'w'))
# Out:
# Total feasible komos - Total error komos - Total komos:
# 67 - 0 - 5831.
# (1.15% feasible)
# [4, 184, 196, 228, 334, 426, 504, 535, 595, 825, 878, 1132, 1199, 1287, 1343, 1505, 2207, 2417, 2441, 2485, 2526, 2551, 2666, 2721, 2735, 2822, 2876, 2881, 2929, 3014, 3080, 3121, 3266, 3351, 3353, 3421, 3713, 3827, 3917, 3969, 4180, 4272, 4372, 4381, 4411, 4450, 4461, 4532, 4644, 4727, 4738, 4793, 4862, 4872, 4909, 4967, 4977, 4994, 5076, 5103, 5293, 5316, 5326, 5381, 5429, 5665, 5819]

# %%
outfolder = "komo_samples_pivot_big_kitchen"
text_outfolder = os.path.join(outfolder, "texts")
feasible_komos = json.load(open(os.path.join(outfolder, "feasibles.json"), 'r'))["feasible_komos"]

# %% [markdown]
# ## Solve submotions

# %%
for i in feasible_komos:

    filename = os.path.join(text_outfolder, f"komo{i}.txt")
    with open(filename, "r") as file:
        komo_text = file.read()
    print(f"__________ SAMPLE {i} __________")
    print(komo_text)

    komo = ry.KOMO(C, 1, 1, 0, False)
    exec(komo_text)
    ret = ry.NLP_Solver(komo.nlp(), verbose=0).solve()

    komo.view(True)
    komo.view_play(True, delay=.5)

# %% [markdown]
# ## Visualize feasible KOMOs

# %%
feasible_samples_count = 10
if len(feasible_komos) < feasible_samples_count:
    feasible_samples = feasible_komos.copy()
else:
    feasible_samples = np.random.choice(feasible_komos, feasible_samples_count, replace=False)

for i in feasible_samples:

    filename = os.path.join(text_outfolder, f"komo{i}.txt")
    with open(filename, "r") as file:
        komo_text = file.read()
    print(f"__________ SAMPLE {i} __________")
    print(komo_text)

    komo = ry.KOMO(C, 1, 1, 0, False)
    exec(komo_text)
    ret = ry.NLP_Solver(komo.nlp(), verbose=0).solve()

    komo.view(True)
    komo.view_play(True, delay=.5)
# Out:
# __________ SAMPLE 3351 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_3_main_group_1_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_3_main_group_1_doorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_3_main_group_1_doorhinge'], ry.OT.eq, [1e1], [0.265])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['r_gripper', 'stack_3_main_group_1_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 2666 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_1_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_1_main_group_2_slidejoint'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_1_main_group_2_slidejoint'], ry.OT.eq, [1e1], [-0.093])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['l_gripper', 'stack_1_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 4532 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_2_main_group_1_left_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_2_main_group_1_leftdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_2_main_group_1_leftdoorhinge'], ry.OT.eq, [1e1], [-0.055])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['l_gripper', 'stack_2_main_group_1_left_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 4738 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_3_main_group_1_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_3_main_group_1_doorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_3_main_group_1_doorhinge'], ry.OT.eq, [1e1], [0.527])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['r_gripper', 'stack_3_main_group_1_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 4967 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_2_main_group_1_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_2_main_group_1_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_2_main_group_1_rightdoorhinge'], ry.OT.eq, [1e1], [0.674])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['r_gripper', 'stack_2_main_group_1_right_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 1505 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_4_main_group_1_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_4_main_group_1_doorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_4_main_group_1_doorhinge'], ry.OT.eq, [1e1], [1.28])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['l_gripper', 'stack_4_main_group_1_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 3421 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_2_main_group_1_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_2_main_group_1_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_2_main_group_1_rightdoorhinge'], ry.OT.eq, [1e1], [1.93])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['r_gripper', 'stack_2_main_group_1_right_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['r_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 1199 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_4_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [-0.52])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['l_gripper', 'stack_4_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 4372 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_4_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_4_main_group_2_slidejoint'], ry.OT.eq, [1e1], [-0.166])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['l_gripper', 'stack_4_main_group_2_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
#
# __________ SAMPLE 3713 __________
# komo = ry.KOMO(C, 2, 1, 2, True)
# komo.addControlObjective([], 0, 1e-1)
# komo.addControlObjective([], 1, 1e-1)
# komo.addControlObjective([], 2, 1e0)
# komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
# komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
# komo.addObjective([], ry.FS.position, ['omnibase'], ry.OT.sos, [1e0], [], 1)
# komo.addObjective([0, 1], ry.FS.pose, ['stack_2_main_group_1_right_door_handle_handle_visual'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([0, 1], ry.FS.qItself, ['stack_2_main_group_1_rightdoorhinge'], ry.OT.eq, [1e1], [], 1)
# komo.addObjective([2], ry.FS.qItself, ['stack_2_main_group_1_rightdoorhinge'], ry.OT.eq, [1e1], [1.989])
# komo.addObjective([1, 2], ry.FS.positionDiff, ['l_gripper', 'stack_2_main_group_1_right_door_handle_handle_visual'], ry.OT.eq, [1e1])
# komo.addObjective([1, 2], ry.FS.angularVel, ['l_gripper'], ry.OT.eq, [1e1])
